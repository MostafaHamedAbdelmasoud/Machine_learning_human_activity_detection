# %% [markdown]
# # Udacity Machine Learning NanoDegree Capstone Project
# # mostafa hamed
#
# ---
#
# Wearable devices have become extremely popular in recent years for tracking user activity.  These small devices use movement and motion data obtained through internal sensors that give insights into the various types of activities that are being performed by the user.  This data exploration Notebook is to better understand the preprocessed version of the dataset, it's features & targets, and how best to proceed with fitting a model to it.
#
# ### Smartphone-Based Recognition of Human Activities and Postural Transitions Data Set
#
# *Note: This data set was obtained from the UCI Machine Learning Repository found here:  http://archive.ics.uci.edu/ml/datasets/Smartphone-Based+Recognition+of+Human+Activities+and+Postural+Transitions*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#sklearn imports 
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import GridSearchCV

# inline graphs in Jupyter Notebook 
# %matplotlib inline

# %%
with open('/content/drive/My Drive/Colab Notebooks/hapt-data (1)/features.txt','r') as f:
    features = [line.strip() for line in f]

# %%
X_train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/hapt-data/Train/X_train.txt', sep=' ', header=None)
X_train.columns= features
X_train.head()
# Out:
#    tBodyAcc-Mean-1  ...  tZAxisAcc-AngleWRTGravity-1
# 0         0.043580  ...                    -0.051718
# 1         0.039480  ...                    -0.047436
# 2         0.039978  ...                    -0.042271
# 3         0.039785  ...                    -0.040826
# 4         0.038758  ...                    -0.037080
#
# [5 rows x 561 columns]

# %%
# load the testing set features 
X_test = pd.read_csv('/content/drive/My Drive/Colab Notebooks/hapt-data/Test/X_test.txt', sep=' ', header=None)
X_test.columns = features 
X_test.head()
# Out:
#    tBodyAcc-Mean-1  ...  tZAxisAcc-AngleWRTGravity-1
# 0         0.030914  ...                    -0.051074
# 1         0.042548  ...                    -0.076825
# 2         0.038297  ...                    -0.072302
# 3         0.036205  ...                    -0.070079
# 4         0.038034  ...                    -0.066849
#
# [5 rows x 561 columns]

# %%
import numpy as np
print('The training set has {} examples'.format(len(X_train)))
print('The testing set has  {} examples'.format(len(X_test)))
print('')
print('The percentage of test to total examples is {:.2f}%'.format(len(X_test) / float(len(X_test) + len(X_train)) * 100) )
# Out:
# The training set has 7767 examples
# The testing set has  3162 examples
#
# The percentage of test to total examples is 28.93%

# %%
with open('/content/drive/My Drive/Colab Notebooks/hapt-data/activity_labels.txt','r') as f:
    activities = [line.strip() for line in f]
activity_dict ={}
    
for activity in activities:
    if int(activity[0:2]) <= 9:
        activity_dict[activity[0]] = activity[2:]
        print('Activity #{} corresponds to {}'.format(activity[0] + ' ', activity[2:]))
    else:
        activity_dict[activity[0:2]] = activity[3:]
        print('Activity #{} corresponds to {}'.format(activity[0:2] + ' ', activity[3:]))
# Out:
# Activity #1  corresponds to WALKING
# Activity #2  corresponds to WALKING_UPSTAIRS
# Activity #3  corresponds to WALKING_DOWNSTAIRS
# Activity #4  corresponds to SITTING
# Activity #5  corresponds to STANDING
# Activity #6  corresponds to LAYING
# Activity #7  corresponds to STAND_TO_SIT
# Activity #8  corresponds to SIT_TO_STAND
# Activity #9  corresponds to SIT_TO_LIE
# Activity #10  corresponds to LIE_TO_SIT
# Activity #11  corresponds to STAND_TO_LIE
# Activity #12  corresponds to LIE_TO_STAND

# %%
# load the training set targets
y_train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/hapt-data/Train/y_train.txt', sep=' ', header=None)
y_train.columns = ['activity']

# %%
# load the testing set targets
y_test = pd.read_csv('/content/drive/My Drive/Colab Notebooks/hapt-data/Test/y_test.txt', sep=' ', header=None)
y_test.columns = ['activity']

# %%
import numpy as np
import re

activity_type, counts = np.unique(y_train.activity.values, return_counts=True)

sns.set_style('white')
plt.figure(figsize=(10, 4))

plt.bar(activity_type, counts, color='mediumaquamarine')
plt.suptitle('Activity Type vs Number of Examples', fontsize=16)
plt.xticks([(x + 1.5) for x in range(len(counts) + 1)], 
           [re.sub('[^A-Za-z\s]', ' ', x.split()[1]).title() for x in activities],
           rotation=90, fontsize=12)
plt.xlabel('Activity Type', fontsize=14)
plt.xlim([0.75, 13])
plt.ylabel('Number of Examples', fontsize=14)

plt.show()

# %%
# plots of the variables 
def plot_variables_vs_activity(variables, title, sharex=True, sharey=True):
    fig, axes = plt.subplots(nrows=4, ncols=3, sharey=sharey, sharex=sharex)
    fig.set_size_inches(20, 14)
    
    # give the plot a title
    plt.suptitle(title, fontsize=18)

    # initialize locations. 
    x_location = 0
    y_location = 0

    for activity_number in range(1, len(counts) + 1):
        # plot the current activity
        X_train[y_train['activity'] == activity_number][variables].plot(
            use_index=False, ax=axes[y_location, x_location])
        
        # set the activity title
        axes[y_location, x_location].set_title(activities[activity_number - 1])

        # update the x & y locations for subplots 
        if x_location < 2: 
            x_location += 1
        else:
            x_location = 0
            y_location += 1
            
variables = ['fBodyAcc-Mean-1', 'fBodyAcc-Mean-2', 'fBodyAcc-Mean-3']
title = 'Plots of 3 Axis Body Acceleration Mean Values with Respect to Frequency vs the Activity Type'

plot_variables_vs_activity(variables, title)

# %%
# t body acc max value 
variables = ['tBodyAcc-Max-1', 'tBodyAcc-Max-2', 'tBodyAcc-Max-3']
title = 'Plots of 3 Axis Body Acceleartion Max Values with respect to time vs the Activity Type'

plot_variables_vs_activity(variables, title, sharex=False)

# %%
# tbody Acc Mag Max, tbody Gyro Mag Max
variables = ['tBodyAccMag-Max-1', 'tBodyGyroMag-Max-1', 'fBodyAccMag-Max-1', 'fBodyGyroMag-Max-1']
title = 'Plots of Body Acceleration and Gyroscope Magnitude Max Values vs the Activity Type'

plot_variables_vs_activity(variables, title)

# %%
# Full PCA of same shape to see how much variance is captured by each PCA  
pca = PCA(n_components = X_train.shape[1], whiten=True)

pca.fit(X_train)

#plot PCA component vs it's explained Variance 
plt.figure(figsize=(17, 6))

# plot limits 
plt.xlim([-5, 600])
plt.ylim([-0.01, 0.6])

# plot priniciple components 
plt.scatter([x for x in range(X_train.shape[1])], pca.explained_variance_ratio_, s=15, color='tomato') 
plt.plot([x for x in range(X_train.shape[1])], pca.explained_variance_ratio_, '-', c='tomato', linewidth=0.75)

# a few annotations 
colors = ['#EC5f67', '#F99157', '#FAC863', '#99C794', '#5FB3B3', 
          '#6699CC', '#C594C5', '#AB7967', '#CDD3DE', '#A7ADBA']

# location tuples 
locs = [(10, 200), (70, 180), (90, 170), (100, 135), (140, 100), 
       (80, 60), (30, 130), (10, 130), (-10, 130), (-25, 130)]

# points to mark 
points = [2, 3, 20, 38, 50, 100, 200, 300, 400, 500]

for i, anno in enumerate(points):
    plt.annotate('PC: {}, EV: {:.2f}%'.format(anno, np.sum(pca.explained_variance_ratio_[:anno]) * 100), 
                xy = (anno, pca.explained_variance_ratio_[anno - 1]), xytext = locs[i],
                textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12,
                bbox = dict(boxstyle = 'round,pad=0.5', fc = colors[i], alpha = 0.9),
                arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0', linewidth=1, color='grey'))

# set up plot annotations 
plt.suptitle("561 Principle Components and Their Explained Variance Ratio", fontsize=16)
plt.xlabel('Principle Component #', fontsize=13)
plt.ylabel('Explained Variance Ratio', fontsize=13)

plt.show()

# %%
# 2 & 3 component PCA as these are still in a realm to plot and visualize
print('{:.2f}% of the variance in the data can be explained by  2 prinicple components'.format(
    (pca.explained_variance_ratio_[0] + pca.explained_variance_ratio_[1]) * 100) )
print('{:.2f}% of the variance in the data can be explained by  3 prinicple components'.format(
    (pca.explained_variance_ratio_[0] + pca.explained_variance_ratio_[1] +
    pca.explained_variance_ratio_[2]) * 100) )

# how many PCA's do we need to include to capture 90% of the explained varience 
variance_total = 0
for i, value in enumerate(pca.explained_variance_ratio_):
    variance_total += value
    if variance_total >= .9:  # stop at 90%
        print('{:.2f}% of the variance in the data can be explained by {} prinicple components'.format(
            variance_total * 100, i + 1) )
        break #exit loop
# Out:
# 65.06% of the variance in the data can be explained by  2 prinicple components
# 69.55% of the variance in the data can be explained by  3 prinicple components
# 90.21% of the variance in the data can be explained by 38 prinicple components

# %%
# Although PCA for 3 components only captures ~70% of the explained variance
# for visualization and understanding purposes a PCA reduction to 2 was performed   
from sklearn.decomposition import PCA
pca_2 = PCA(n_components = 2, whiten=True)

pca_2.fit(X_train)

# Print the components and the amount of variance in the data contained in each dimension
print(pca_2.components_)
print(pca_2.explained_variance_ratio_)
# Out:
# [[-0.00015235  0.00013133  0.00022622 ... -0.03660483  0.02668244
#    0.02207401]
#  [ 0.00125588  0.00270589  0.00196012 ...  0.05143451 -0.02052715
#   -0.02527979]]
# [0.58635593 0.06425612]

# %%
# import mpatches for legend creation
import matplotlib.patches as mpatches

# set seaborn styling to white 
sns.set_style('white')

# activites removed numbers and title cased
cleaned_activities = [re.sub('[^A-Za-z\s]', ' ', x.split()[1]).title() for x in activities]

# Inital plot of Activity 1 
ax = pd.DataFrame(pca_2.transform(X_train[y_train['activity'] == 1]), columns=['PC1', 'PC2']).plot(
        kind='scatter', x='PC1', y='PC2', figsize=(10, 7), s=25.0, 
        alpha=0.5, color='lightseagreen', ylim=[-5, 5], xlim=[-1.5, 3.5])

# colors 
colors = ['lightseagreen', 'deepskyblue', 'cyan', 'firebrick', 'tomato', 'indianred',
          'darkmagenta', 'plum', 'indigo', 'orchid', 'fuchsia', 'black']

for i, color in enumerate(colors[1:]):
    pd.DataFrame(pca_2.transform(X_train[y_train['activity'] == (i + 2)]), columns=['PC1', 'PC2']).plot(
            kind='scatter', x='PC1', y='PC2', figsize=(10, 7), s=25.0, 
            alpha=0.5, color=color, ylim=[-5, 5], xlim=[-1.5, 3.5], ax=ax)
    

colors_modified = list(colors)
colors_modified.insert(3, 'white')
cleaned_activities.insert(3, '')
colors_modified.insert(7, 'white')
cleaned_activities.insert(7, '')

mpat_list = []
for i, color in enumerate(colors_modified):
    mpat_list.append(mpatches.Patch(color=color, label=cleaned_activities[i]))

plt.suptitle('2D Reduced PCA of the HATP Preprocessed Dataset', fontsize=16)
plt.legend(handles = mpat_list)

plt.show()

# %%
# plot 2d PCA with Feature vectors 
ax = pd.DataFrame(pca_2.transform(X_train), columns=['PC1', 'PC2']).plot(
        kind='scatter', x='PC1', y='PC2', figsize=(10, 7), s=25.0, 
        alpha=0.5, color='lightseagreen', ylim=[-5, 5], xlim=[-1.5, 3.5])
plt.suptitle('2D Reduced PCA of the HATP Preprocessed Dataset w/Feature Vectors', fontsize=16)

for i, (pc1, pc2) in enumerate(zip(pca.components_[0], pca.components_[1])):
            ax.arrow(0, 0, pc1*30, pc2*30, width=0.003, fc='firebrick', ec='tomato', alpha=0.6)
            #ax.annotate(X_train.columns[i], (pc1*20, pc2*20), size=5)

plt.show()

# %%
# Although PCA for 3 components only captures ~70% of the explained variance
# it's still in a space that can be iniutively understood and visualized. 
from sklearn.decomposition import PCA
pca_3 = PCA(n_components = 3, whiten=True)

pca_3.fit(X_train)

# Print the components and the amount of variance in the data contained in each dimension
print(pca_3.components_)
print(pca_3.explained_variance_ratio_)
# Out:
# [[-1.52350723e-04  1.31333804e-04  2.26220409e-04 ... -3.66048330e-02
#    2.66824414e-02  2.20740051e-02]
#  [ 1.25587754e-03  2.70588961e-03  1.96011613e-03 ...  5.14345121e-02
#   -2.05271475e-02 -2.52797908e-02]
#  [ 6.95889917e-03 -4.84213150e-03 -3.60302332e-03 ...  2.80486574e-01
#   -1.36272838e-01 -1.09363381e-01]]
# [0.58635593 0.06425612 0.04489017]

# %%
# plot 3-dimensional PCA 
pca_3d = plt.figure(figsize=(10, 7)).gca(projection='3d')

# iterate through color and activity type 
for i, color in enumerate(colors):  
    pca_3d_df = pd.DataFrame(pca_3.transform(X_train[y_train['activity'] == (i + 1)]), columns=['PC1', 'PC2', 'PC3'])
    pca_3d.scatter(pca_3d_df['PC1'], pca_3d_df['PC2'], pca_3d_df['PC3'], c=color)

# set labels and titles 
plt.suptitle('3D Reduced PCA of the HATP Dataset', fontsize=16)
pca_3d.set_xlabel('PC1', fontsize=13, labelpad=10)
pca_3d.set_ylabel('PC2', fontsize=13, labelpad=10)
pca_3d.set_zlabel('PC3', fontsize=13, labelpad=10)

# set pane colors
pca_3d.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
pca_3d.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
pca_3d.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

# set grid colors 
pca_3d.w_xaxis.gridlines.set_lw(1.0)
pca_3d.w_yaxis.gridlines.set_lw(1.0)
pca_3d.w_zaxis.gridlines.set_lw(1.0)

# add legend
plt.legend(handles = mpat_list, bbox_to_anchor=(0.92, 0.97))

plt.show()

# %%
# Training Function 
import time

# a function to keep track of training time
# always a good metric to keep track of for choosing between similar performing models
def train_classifier(clf, X_train, y_train):
    print ("Training {}...".format(clf.__class__.__name__))
    
    # time and training of the classifier 
    start = time.time()
    clf.fit(X_train, y_train)
    end = time.time()
    
    total_training_time = end - start
    print ("Done!\nTraining time (secs): {:.3f}".format(total_training_time))
    
    return total_training_time # return to keep track

# %%
# Plotting functions 
tick_activities = [re.sub('[^A-Za-z\s]', ' ', x)[2:].title() for x in activities]

# Simplified confusion matrix array
def normalize_cm(confusion_matrix):
    return (confusion_matrix.astype('float') /
            confusion_matrix.sum(axis=1)[:, np.newaxis])

def plot_confusion_matricies(training_cm, test_cm, title, questionable_annot_colors=None):
    
    # setup sub axes 
    fig, axes = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True)
    fig.set_size_inches(20, 7) # Plot figure Size 

    # Normalize the confusion matricies by row (i.e by the number of samples in each class)
    training_cm_normalized = normalize_cm(training_cm)
    test_cm_normalized = normalize_cm(test_cm)

    # plot 
    sns.heatmap(training_cm_normalized, annot=False, fmt='g', cmap='Blues', ax=axes[0])
    sns.heatmap(training_cm, annot=True, annot_kws={"size": 12, "color": "#111111"}, 
                fmt='g', alpha=0.0, cbar=False, ax=axes[0])
    
    sns.heatmap(test_cm_normalized, annot=False, fmt='g', cmap='Greens', ax=axes[1])
    sns.heatmap(test_cm, annot=True, annot_kws={"size": 12, "color": "#111111"}, 
                fmt='g', alpha=0.0, cbar=False, ax=axes[1])

    if questionable_annot_colors != None:
        for ax_num in range(2):
            for text in axes[ax_num].texts:
                if text.get_text() in questionable_annot_colors:
                    text.set_color('#fefefe')

    # labels and titles
    fig.suptitle(title, fontsize=20, x=0.47, y=1.02)
    axes[0].set_xticklabels(tick_activities, rotation=90, fontsize=12)
    axes[0].set_yticklabels(tick_activities[::-1], rotation=0, fontsize=12)
    axes[0].set_title('Training Confusion Matrix', fontsize=16)
    
    # axis labels 
    axes[0].set_ylabel('True Labels', fontsize=15)
    fig.text(0.47, -0.10, 'Predicted Labels', ha='center', fontsize=15)
   
    # second axis 
    axes[1].set_xticklabels(tick_activities, rotation=90, fontsize=12)
    axes[1].set_title('Testing Confusion Matrix', fontsize=16)
    
    # remove space and show 
    fig.subplots_adjust(wspace=0, hspace=0)
    plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# function used to output accuracy score, prediction time and resulting confusion matrix
# items are output as a tupled (accuracy, f1 score, confusion matrix, total pred time)
def predict_labels(clf, features, target, is_training=True):
    if is_training: 
        which_prediction = 'Training Set'
    else:
        which_prediction = 'Testing Set'
    print ("Predicting labels for {} using {}...".format(which_prediction, clf.__class__.__name__))
    
    # time and classifier prediction 
    start = time.time()
    y_pred = clf.predict(features)
    end = time.time()
    total_prediction_time = end - start 
    
    print ("Done!\nPrediction time for {} (secs): {:.3f}".format(which_prediction, total_prediction_time))
    return (accuracy_score(target.values, y_pred),
           f1_score(target.values, y_pred, average='weighted'),
           confusion_matrix(target.values, y_pred),
           total_prediction_time)

# %%
# LinearSVC classifier
clf_pca_3 = LinearSVC()

# Fit model to training data
# transform X_train with the PCA, reshapes the y_train dataframe into a 1D array
lsvc_train_time = train_classifier(clf_pca_3, pca_3.transform(X_train), y_train.activity.values) 
print (clf_pca_3)
# Out:
# Training LinearSVC...
# Done!
# Training time (secs): 0.510
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
# Training Accuracy for LinearSVC 
pca_3_train_output_lsvc = predict_labels(clf_pca_3, pca_3.transform(X_train), y_train)
print ("Accuracy score for training set: {}".format(pca_3_train_output_lsvc[0]))
print ("F1 score for training set:       {}".format(pca_3_train_output_lsvc[1]))

# whitespace 
print('')
print('')

# Test accuracy for LinearSVC 
pca_3_test_output_lsvc = predict_labels(clf_pca_3, pca_3.transform(X_test), y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(pca_3_test_output_lsvc[0]))
print ("F1 score for Testing set:       {:.10f}".format(pca_3_test_output_lsvc[1]))
# Out:
# Predicting labels for Training Set using LinearSVC...
# Done!
# Prediction time for Training Set (secs): 0.002
# Accuracy score for training set: 0.7404403244495944
# F1 score for training set:       0.7220820748577026
#
#
# Predicting labels for Testing Set using LinearSVC...
# Done!
# Prediction time for Testing Set (secs): 0.001
# Accuracy score for Testing set: 0.7425679949
# F1 score for Testing set:       0.7197927296
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
title = 'Training & Testing Confusion Matricies for LinearSVC Classification on 3 Component PCA'
questionable_annot_colors = ['45', '23', '22', '62', '1311', '1404', '78', '540', '23', '10',
                             '507', '30', '434', '387', '43']
plot_confusion_matricies(pca_3_train_output_lsvc[2],
                         pca_3_test_output_lsvc[2],
                         title, questionable_annot_colors=questionable_annot_colors)

# %% [markdown]
# ### Naive Bayes Classifier

# %%
# NB classifier
clf_pca_3_nb = GaussianNB()

# Fit model to training data
# transform X_train with the PCA, reshapes the y_train dataframe into a 1D array
nb_train_time = train_classifier(clf_pca_3_nb, pca_3.transform(X_train), y_train.activity.values) 
print (clf_pca_3_nb)
# Out:
# Training GaussianNB...
# Done!
# Training time (secs): 0.006
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Training metrics for NB Classifier 
pca_3_train_output_nb = predict_labels(clf_pca_3_nb, pca_3.transform(X_train), y_train)
print ("Accuracy score for training set: {}".format(pca_3_train_output_nb[0]))
print ("F1 score for training set:       {}".format(pca_3_train_output_nb[1]))

# whitespace 
print('')
print('')

# Testing metics for NB Classifier
pca_3_test_output_nb = predict_labels(clf_pca_3_nb, pca_3.transform(X_test), y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(pca_3_test_output_nb[0]))
print ("F1 score for Testing set:       {:.10f}".format(pca_3_test_output_nb[1]))
# Out:
# Predicting labels for Training Set using GaussianNB...
# Done!
# Prediction time for Training Set (secs): 0.007
# Accuracy score for training set: 0.7072228659714175
# F1 score for training set:       0.7045466014241805
#
#
# Predicting labels for Testing Set using GaussianNB...
# Done!
# Prediction time for Testing Set (secs): 0.004
# Accuracy score for Testing set: 0.7074636306
# F1 score for Testing set:       0.6990404042

# %%
title = 'Training & Testing Set Confusion Matricies for Gaussian NB Classification on 3 Component PCA'
questionable_annot_colors = ['1224', '1362', '508', '516']
plot_confusion_matricies(pca_3_train_output_nb[2],
                          pca_3_test_output_nb[2],
                          title, questionable_annot_colors)

# %% [markdown]
# ### Support Vector Machine

# %%
# SVM classifier
clf_pca_3_svc = SVC()

# Fit model to training data
# transform X_train with the PCA, reshapes the y_train dataframe into a 1D array
svc_train_time = train_classifier(clf_pca_3_svc, pca_3.transform(X_train), y_train.activity.values) 
print (clf_pca_3_svc)
# Out:
# Training SVC...
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Done!
# Training time (secs): 0.573
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
pca_3_train_output_svc = predict_labels(clf_pca_3_svc, pca_3.transform(X_train), y_train)
print ("Accuracy score for training set: {}".format(pca_3_train_output_svc[0]))
print ("F1 score for training set:       {}".format(pca_3_train_output_svc[1]))

# whitespace 
print('')
print('')

pca_3_test_output_svc = predict_labels(clf_pca_3_svc, pca_3.transform(X_test), y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(pca_3_test_output_svc[0]))
print ("F1 score for Testing set:       {:.10f}".format(pca_3_test_output_svc[1]))
# Out:
# Predicting labels for Training Set using SVC...
# Done!
# Prediction time for Training Set (secs): 1.190
# Accuracy score for training set: 0.782412771984035
# F1 score for training set:       0.7761482366075362
#
#
# Predicting labels for Testing Set using SVC...
# Done!
# Prediction time for Testing Set (secs): 0.507
# Accuracy score for Testing set: 0.7602783049
# F1 score for Testing set:       0.7510807696

# %%
title = "Training & Testing Set Confusion Matricies for SVC with 'rbf' kernel Classification on 3 Component PCA"
questionable_annot_colors = ['968', '875', '1306', '1404', '445', '508', '532', '384']
plot_confusion_matricies(pca_3_train_output_svc[2], 
                         pca_3_test_output_svc[2],
                         title, questionable_annot_colors)

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# LinearSVC classifier
clf_pca_3_rf =  RandomForestClassifier()

# Fit model to training data
# transform X_train with the PCA, reshapes the y_train dataframe into a 1D array
rf_train_time = train_classifier(clf_pca_3_rf, pca_3.transform(X_train), y_train.activity.values) 
print (clf_pca_3_rf)
# Out:
# Training RandomForestClassifier...
# Done!
# Training time (secs): 0.138
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Training metrics Random Forest
pca_3_train_output_rf = predict_labels(clf_pca_3_rf, pca_3.transform(X_train), y_train)
print ("Accuracy score for training set: {}".format(pca_3_train_output_rf[0]))
print ("F1 score for training set:       {}".format(pca_3_train_output_rf[1]))

# whitespace 
print('')
print('')

# Testing metrics Random Forest 
pca_3_test_output_rf = predict_labels(clf_pca_3_rf, pca_3.transform(X_test), y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(pca_3_test_output_rf[0]))
print ("F1 score for Testing set:       {:.10f}".format(pca_3_test_output_rf[1]))
# Out:
# Predicting labels for Training Set using RandomForestClassifier...
# Done!
# Prediction time for Training Set (secs): 0.024
# Accuracy score for training set: 0.9859662675421655
# F1 score for training set:       0.9859466865045101
#
#
# Predicting labels for Testing Set using RandomForestClassifier...
# Done!
# Prediction time for Testing Set (secs): 0.011
# Accuracy score for Testing set: 0.7128399747
# F1 score for Testing set:       0.7099053608

# %%
# Plotting Random Forest CMs
title = 'Training & Testing Set Confusion Matricies for Random Forest Classification on 3 Component PCA'
questionable_annot_colors = ([str(pca_3_train_output_rf[2][x, x]) for x in range(12)] + 
                            ['423', '513'])
plot_confusion_matricies(pca_3_train_output_rf[2],
                         pca_3_test_output_rf[2],
                         title, questionable_annot_colors)

# %% [markdown]
# ### Associated Plots for Algorithm performance comparison on the 3 Component PCA data.

# %%
# a plot of the different Testing & Training Accuracies
training_accuracies = [pca_3_train_output_lsvc[0],
                       pca_3_train_output_nb[0],
                       pca_3_train_output_svc[0],
                       pca_3_train_output_rf[0]]

testing_accuracies = [pca_3_test_output_lsvc[0],
                      pca_3_test_output_nb[0],
                      pca_3_test_output_svc[0],
                      pca_3_test_output_rf[0]] 

algorithm_list = ['Linear SVC', 'Naive Bayes', 'SVC', 'Random Forests']

plt.figure(figsize=(10, 5))

plt.plot(training_accuracies, '-o', color='lightseagreen', label='Training Accuracy')
plt.plot(testing_accuracies, '-o', color='tomato', label='Testing Accuracy')

for i in range(len(testing_accuracies)):
    plt.annotate('{:.3f}'.format(testing_accuracies[i]), 
            xy = (i, testing_accuracies[i]), xytext = (-10 * i , -40),
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12,
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'tomato', alpha = 0.9),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='grey'))
    
for i in range(len(training_accuracies)):
    plt.annotate('{:.3f}'.format(training_accuracies[i]), 
            xy = (i, training_accuracies[i]), xytext = (-10 * i , 30),
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12,
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'lightseagreen', alpha = 0.9),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='grey'))

plt.axhline(1.0, color='slategrey', linestyle='dashed', linewidth=1)

plt.ylim(0.6, 1.09)
plt.ylabel('Accuracy Score', fontsize=15)

plt.xlim(-0.3, 3.3)
plt.xticks(range(4), algorithm_list, rotation=0, fontsize=13)
plt.xlabel('Algorithm Type', fontsize=15)

plt.suptitle('Algorithm Testing & Training Accuracies on 3 Component PCA Reduced Data', fontsize=18)
plt.legend(bbox_to_anchor=(0.25, 0.99), fontsize=11)

plt.show()

# %%
# a plot of the different Testing & Training Times 
training_times = [lsvc_train_time,
                  nb_train_time,
                  svc_train_time,
                  rf_train_time]

training_prediction_times = [pca_3_train_output_lsvc[3],
                             pca_3_train_output_nb[3],
                             pca_3_train_output_svc[3],
                             pca_3_train_output_rf[3]]

testing_prediction_times = [pca_3_test_output_lsvc[3],
                            pca_3_test_output_nb[3],
                            pca_3_test_output_svc[3],
                            pca_3_test_output_rf[3]] 

plt.figure(figsize=(10, 5))

plt.plot(training_times, '-o', color='lightseagreen', label='Training Times')
plt.plot(training_prediction_times, '-o', color='tomato', label='Train Set Prediction Times')
plt.plot(testing_prediction_times, '-o', color='violet', label='Test Set Prediction Times')

def annotate_points(what_to_anno, locs, color): 
    for i in range(len(what_to_anno)):
        plt.annotate('{:.3f}'.format(what_to_anno[i]), 
                xy = (i, what_to_anno[i]), xytext = locs[i],
                textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12,
                bbox = dict(boxstyle = 'round,pad=0.5', fc = color, alpha = 0.8),
                arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='grey'))
        
annotate_points(training_times, [(-10, 30), (-80, 60), (-10, 30), (-10, 30)], 'lightseagreen')
annotate_points(training_prediction_times, [(-30, 30), (-20, 40), (-60, 0), (5, 30)], 'tomato')
annotate_points(testing_prediction_times, [(30, 20), (50, 10), (0, -50), (-80, 5)], 'violet')

plt.axhline(1.0, color='slategrey', linestyle='dashed', linewidth=1)

plt.ylim(-0.02, 1.0)
plt.ylabel('Time (seconds)', fontsize=15)

plt.xlim(-0.3, 3.3)
plt.xticks(range(4), algorithm_list, rotation=0, fontsize=13)
plt.xlabel('Algorithm Type', fontsize=15)

plt.suptitle('Algorithm Training & Prediction Times on 3 Component PCA Reduced Data', fontsize=18)
plt.legend(bbox_to_anchor=(0.33, 0.99), fontsize=11)

plt.show()

# %% [markdown]
# # ============================================================
# # 38 component PCA
#
# ---
#
#
# ### Naive Bayes model on a PCA with 38 components (~90% of the variance captured)

# %%
# PCA with 37 components 
pca_38 = PCA(n_components = 38, whiten=True)

pca_38.fit(X_train)

# Print the components and the amount of variance in the data contained in each dimension
print(pca_38.components_)
print(pca_38.explained_variance_ratio_)
# Out:
# [[-1.52350723e-04  1.31333804e-04  2.26220409e-04 ... -3.66048330e-02
#    2.66824414e-02  2.20740051e-02]
#  [ 1.25587754e-03  2.70588959e-03  1.96011612e-03 ...  5.14345122e-02
#   -2.05271477e-02 -2.52797908e-02]
#  [ 6.95889893e-03 -4.84213130e-03 -3.60302323e-03 ...  2.80486575e-01
#   -1.36272835e-01 -1.09363382e-01]
#  ...
#  [-3.01882279e-02  3.52136010e-02  2.53555463e-02 ... -1.37548602e-02
#   -1.10200318e-03  3.61735792e-02]
#  [-4.45915755e-02  4.01572717e-02  3.12591241e-02 ... -4.32423925e-02
#   -2.31551127e-02 -7.64250668e-02]
#  [ 1.44900344e-02 -4.47644943e-03 -5.52801054e-03 ...  2.94731884e-02
#    4.99239506e-02  4.57195693e-02]]
# [0.58635593 0.06425612 0.04489017 0.02116905 0.01636383 0.01363504
#  0.01251664 0.01158892 0.00998506 0.00910735 0.0080903  0.00740391
#  0.00707084 0.00587646 0.0053497  0.00512337 0.0048714  0.00476667
#  0.00443129 0.00428027 0.00417815 0.0040916  0.00398404 0.00373089
# ...

# %%
# Naive Bayes classifier
clf_pca_38_nb = GaussianNB()

# Fit model to training data
# transform X_train with the PCA, reshapes the y_train dataframe into a 1D array
pca_38_train_time_nb = train_classifier(clf_pca_38_nb, pca_38.transform(X_train), y_train.activity.values) 
print (clf_pca_38_nb)
# Out:
# Training GaussianNB...
# Done!
# Training time (secs): 0.009
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Accuracy on the training set for a 38 component PCA 
pca_38_train_output_nb = predict_labels(clf_pca_38_nb, pca_38.transform(X_train), y_train)
print ("Accuracy score for Training set: {:10f}".format(pca_38_train_output_nb[0]))
print ("F1 score for Training set:       {:10f}".format(pca_38_train_output_nb[1]))

# whitespace 
print('')
print('')

# accuracy on the test set for a 38 component PCA 
pca_38_test_output_nb = predict_labels(clf_pca_38_nb, pca_38.transform(X_test), y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(pca_38_test_output_nb[0]))
print ("F1 score for Testing set:       {:.10f}".format(pca_38_test_output_nb[1]))
# Out:
# Predicting labels for Training Set using GaussianNB...
# Done!
# Prediction time for Training Set (secs): 0.030
# Accuracy score for Training set:   0.875113
# F1 score for Training set:         0.875445
#
#
# Predicting labels for Testing Set using GaussianNB...
# Done!
# Prediction time for Testing Set (secs): 0.012
# Accuracy score for Testing set: 0.8608475648
# F1 score for Testing set:       0.8585638315

# %%
# Plotting Naive Bayes 38 PCA CMs
title = 'Training & Testing Set Confusion Matricies for Gaussian NB Classification on 38 Component PCA'
questionable_annot_colors = ([str(pca_38_train_output_nb[2][x, x]) for x in range(12)] + 
                             [str(pca_38_test_output_nb[2][x, x]) for x in range(12)])
plot_confusion_matricies(pca_38_train_output_nb[2],
                         pca_38_test_output_nb[2],
                         title, questionable_annot_colors)

# %% [markdown]
# ## Gaussian NB model on the entire feature space

# %%
# NB creation 
clf = GaussianNB()

# Fit model to training data
train_times_nb = train_classifier(clf, X_train, y_train.activity.values) # reshapes the y_train dataframe into a 1D array
print (clf)  # you can inspect the learned model by printing it
# Out:
# Training GaussianNB...
# Done!
# Training time (secs): 0.080
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
nb_training_outputs = predict_labels(clf, X_train, y_train)
print ("Accuracy score for training set: {:.10f}".format(nb_training_outputs[0]))
print ("F1 score for the training set:   {:.10f}".format(nb_training_outputs[1]))

# whitespace 
print('')
print('')

nb_test_outputs = predict_labels(clf, X_test, y_test, False)
print ("Accuracy score for test set: {:.10f}".format(nb_test_outputs[0]))
print ("F1 score for test set:       {:.10f}".format(nb_test_outputs[1]))
# Out:
# Predicting labels for Training Set using GaussianNB...
# Done!
# Prediction time for Training Set (secs): 0.420
# Accuracy score for training set: 0.7126303592
# F1 score for the training set:   0.7112609260
#
#
# Predicting labels for Testing Set using GaussianNB...
# Done!
# Prediction time for Testing Set (secs): 0.146
# Accuracy score for test set: 0.7473118280
# F1 score for test set:       0.7427372716

# %%
# Plotting Naive Bayes 561 features 
title = 'Training & Testing Set Confusion Matricies for Gaussian NB Classification for Complete Feature Space'
questionable_annot_colors = ([str(nb_training_outputs[2][x, x]) for x in range(12)] + 
                             [str(nb_test_outputs[2][x, x]) for x in range(12)])
plot_confusion_matricies(nb_training_outputs[2],
                         nb_test_outputs[2],
                         title, questionable_annot_colors)

# %% [markdown]
# ----
#
# ### SVC on a PCA with 38 components (~90% of the variance captured)

# %%
# SVC classifier
clf_pca_38_svc =  SVC()

# Fit model to training data
# transform X_train with the PCA, reshapes the y_train dataframe into a 1D array
svc_train_time = train_classifier(clf_pca_38_svc, pca_38.transform(X_train), y_train.activity.values) 
print (clf_pca_38_svc)
# Out:
# Training SVC...
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Done!
# Training time (secs): 2.272
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# Training metrics SVC
pca_38_train_output_svc = predict_labels(clf_pca_38_svc, pca_38.transform(X_train), y_train)
print ("Accuracy score for training set: {}".format(pca_38_train_output_svc[0]))
print ("F1 score for training set:       {}".format(pca_38_train_output_svc[1]))

# whitespace 
print('')
print('')

# Testing metrics SVC 
pca_38_test_output_svc = predict_labels(clf_pca_38_svc, pca_38.transform(X_test), y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(pca_38_test_output_svc[0]))
print ("F1 score for Testing set:       {:.10f}".format(pca_38_test_output_svc[1]))
# Out:
# Predicting labels for Training Set using SVC...
# Done!
# Prediction time for Training Set (secs): 2.208
# Accuracy score for training set: 0.9824900218874726
# F1 score for training set:       0.982483455552408
#
#
# Predicting labels for Testing Set using SVC...
# Done!
# Prediction time for Testing Set (secs): 0.924
# Accuracy score for Testing set: 0.9165085389
# F1 score for Testing set:       0.9157805704

# %%
# Plotting SVC Testing CMs
title = 'Training & Testing Set Confusion Matricies for SVC on 38 Component PCA'
questionable_annot_colors = ([str(pca_38_train_output_svc[2][x, x]) for x in range(12)] + 
                             [str(pca_38_test_output_svc[2][x, x]) for x in range(12)])
plot_confusion_matricies(pca_38_train_output_svc[2],
                         pca_38_test_output_svc[2],
                         title, questionable_annot_colors)

# %%
# a plot of the different Testing & Training Accuracies
training_accuracies = [pca_38_train_output_nb[0],
                       pca_38_train_output_svc[0]]

testing_accuracies = [pca_38_test_output_nb[0],
                      pca_38_test_output_svc[0]]

algorithm_list = ['Naive Bayes', 'SVC']

plt.figure(figsize=(10, 5))

plt.plot(training_accuracies, '-o', color='lightseagreen', label='Training Accuracy')
plt.plot(testing_accuracies, '-o', color='tomato', label='Testing Accuracy')

for i in range(len(testing_accuracies)):
    plt.annotate('{:.3f}'.format(testing_accuracies[i]), 
            xy = (i, testing_accuracies[i]), xytext = (-10 * i , -40),
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12,
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'tomato', alpha = 0.9),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='grey'))
    
for i in range(len(training_accuracies)):
    plt.annotate('{:.3f}'.format(training_accuracies[i]), 
            xy = (i, training_accuracies[i]), xytext = (-10 * i , 30),
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12,
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'lightseagreen', alpha = 0.9),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='grey'))

plt.axhline(1.0, color='slategrey', linestyle='dashed', linewidth=1)

plt.ylim(0.6, 1.09)
plt.ylabel('Accuracy Score', fontsize=15)

plt.xlim(-0.3, 1.3)
plt.xticks(range(2), algorithm_list, rotation=0, fontsize=13)
plt.xlabel('Algorithm Type', fontsize=15)

plt.suptitle('Algorithm Testing & Training Accuracies on 38 Component PCA Reduced Data', fontsize=18)
plt.legend(bbox_to_anchor=(0.25, 0.99), fontsize=11)

plt.show()

# %% [markdown]
# ============================================================
# ============================================================
# # Exploring Correlation Between Model Accuracy and PCA components
#
# ---
#
# Is there a correlation between the number of components used for the PCA and the model accuracy

# %%
# Naive Bayes Accuracies vs Number of Components
n_from_1_10 = list(range(1, 10, 1))
n_from_10_561 = list(range(10, 561, 25))

n_components = n_from_1_10 + n_from_10_561
nb_train_accuracies = []
nb_test_accuracies = []

for n_component in n_components:
    pca = PCA(n_components = n_component, whiten=True)
    pca.fit(X_train)
    
    clf = GaussianNB()
    clf.fit(pca.transform(X_train), y_train.activity.values)
    
    # calculate training accuracy 
    y_pred = clf.predict(pca.transform(X_train))
    nb_train_accuracy = accuracy_score(y_train.activity.values, y_pred)
    nb_train_accuracies.append(nb_train_accuracy)
    
    # calculate Testing Accuracy 
    y_pred = clf.predict(pca.transform(X_test))
    nb_test_accuracy = accuracy_score(y_test.activity.values, y_pred)
    nb_test_accuracies.append(nb_test_accuracy)

# %%
# SVC accuracies vs Number of Prinicple Components
# *WARNING* This block takes about 10-15 mins to execute. Consider yourself warned... 
svc_train_accuracies = []
svc_test_accuracies = []

for n_component in n_components:
    pca = PCA(n_components = n_component, whiten=True)
    pca.fit(X_train)
    
    if (n_component % 10 == 0): # sanity check, things are still happening 
        print(n_component) 
    
    clf = SVC()
    clf.fit(pca.transform(X_train), y_train.activity.values)
    
    # calculate training accuracy 
    y_pred = clf.predict(pca.transform(X_train))
    svc_train_accuracy = accuracy_score(y_train.activity.values, y_pred)
    svc_train_accuracies.append(svc_train_accuracy)
    
    # calculate Testing Accuracy 
    y_pred = clf.predict(pca.transform(X_test))
    svc_test_accuracy = accuracy_score(y_test.activity.values, y_pred)
    svc_test_accuracies.append(svc_test_accuracy)7
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
# setup figure with side by side plot 
fig, axes = plt.subplots(nrows=1, ncols=2, sharey=False)
fig.set_size_inches(20, 6) # Plot figure Size 

plt.suptitle('Test & Training Accuracies for Naive Bayes and SVC vs Number of Principle Components',
             y=1.02, fontsize=18)
axes[0].plot(n_components, nb_train_accuracies, '-o', color='lightseagreen', label='Training Accuracy')
axes[0].plot(n_components, nb_test_accuracies, '-o', color='tomato', label='Test Accuracy')
axes[1].plot(n_components, svc_train_accuracies, '-o', color='lightseagreen', label='Training Accuracy')
axes[1].plot(n_components, svc_test_accuracies, '-o', color='tomato', label='Test Accuracy')

# find maximums in each list 
nb_train_max_index = nb_train_accuracies.index(max(nb_train_accuracies))
nb_test_max_index = nb_test_accuracies.index(max(nb_test_accuracies))
svc_train_max_index = svc_train_accuracies.index(max(svc_train_accuracies))
svc_test_max_index = svc_test_accuracies.index(max(svc_test_accuracies))

# maximum lines 
axes[0].axvline(n_components[nb_train_max_index], linestyle='dashed', color='lightseagreen')
axes[0].axvline(n_components[nb_test_max_index], linestyle='dashed', color='tomato')
axes[1].axvline(n_components[svc_train_max_index], linestyle='dashed', color='lightseagreen')
axes[1].axvline(n_components[svc_test_max_index], linestyle='dashed', color='tomato')

# set axis ranges and titles  
axes[0].set_ylim(0.45, 1.01)
axes[1].set_ylim(0.45, 1.01)
axes[0].set_xlim(0, 560)
axes[1].set_xlim(0, 560)
axes[0].set_ylabel('Accuracy', fontsize=15)
fig.text(0.50, 0.05, 'Number of Principle Components', ha='center', fontsize=15)
axes[0].set_title('Naive Bayes', fontsize=14)
axes[1].set_title('SVC', fontsize=14)

# annotations 
axes[0].annotate('Max train accuracy: {:.3f}, PC: {}'.format(
            nb_train_accuracies[nb_train_max_index], n_components[nb_train_max_index]), 
            xy = (n_components[nb_train_max_index], nb_train_accuracies[nb_train_max_index]), xytext = (25, 30),
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12, 
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'lightseagreen', alpha = 0.8),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='darkgrey'))

axes[0].annotate('Max test accuracy: {:.3f}, PC: {}'.format(
            nb_test_accuracies[nb_test_max_index], n_components[nb_test_max_index]), 
            xy = (n_components[nb_test_max_index], nb_test_accuracies[nb_test_max_index]), xytext = (50, -110),
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12, 
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'tomato', alpha = 0.8),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='darkgrey'))

axes[1].annotate('Max train accuracy: {:.3f}, PC: {}'.format(
            svc_train_accuracies[svc_train_max_index], n_components[svc_train_max_index]), 
            xy = (n_components[svc_train_max_index], svc_train_accuracies[svc_train_max_index]), xytext = (20, -40),
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12, 
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'lightseagreen', alpha = 0.8),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='darkgrey'))

axes[1].annotate('Max test accuracy: {:.3f}, PC: {}'.format(
            svc_test_accuracies[svc_test_max_index], n_components[svc_test_max_index]), 
            xy = (n_components[svc_test_max_index], svc_test_accuracies[svc_test_max_index]), xytext = (130, -100),
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12, 
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'tomato', alpha = 0.8),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='darkgrey'))

axes[0].legend(bbox_to_anchor=(0.98, 0.15), fontsize=11)
axes[1].legend(bbox_to_anchor=(0.98, 0.15), fontsize=11)
plt.show()

# %% [markdown]
# ============================================================
# ============================================================
# # Set Phasers to Stun - Train SVC to 110 component PCA with GridSearch for Optimized parameters.
#
# ---
#
# It's clear that SVC has some big accuracy advantages over Naive Bayes.  Therefore I'm going after this one.

# %%
pca_110 = PCA(n_components = 110, whiten=True)
pca_110.fit(X_train)

# C and gamma parameter rangers 
C_range = np.logspace(0, 3, 4)
gamma_range = np.logspace(-3, 1, 5)

parameter_grid = {'gamma': gamma_range, 'C': C_range}
scorer = make_scorer(accuracy_score)
svc = SVC()
clf = GridSearchCV(svc, parameter_grid, scoring=scorer)

clf.fit(pca_110.transform(X_train), y_train.activity.values)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': array([   1.,   10.,  100., 1000.]),
#                          'gamma': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
# ...

# %%
print(clf.best_estimator_)
print('')
print(clf.best_params_)
print('')
print(clf.best_score_)
# Out:
# SVC(C=100.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
# {'C': 100.0, 'gamma': 0.001}
#
# 0.9219775975280031

# %%
clf_svc_tuned = clf.best_estimator_
pca_110_clf_svc_tuned_train_time = train_classifier(clf_svc_tuned, 
                                                    pca_110.transform(X_train), 
                                                    y_train.activity.values)
print(clf_svc_tuned)
# Out:
# Training SVC...
# Done!
# Training time (secs): 2.553
# SVC(C=100.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# Training metrics SVC
pca_110_train_output_svc_tuned = predict_labels(clf_svc_tuned, pca_110.transform(X_train), y_train)
print ("Accuracy score for training set: {}".format(pca_110_train_output_svc_tuned[0]))
print ("F1 score for training set:       {}".format(pca_110_train_output_svc_tuned[1]))

# whitespace 
print('')
print('')
# Testing metrics SVC 
pca_110_test_output_svc_tuned = predict_labels(clf_svc_tuned, pca_110.transform(X_test), y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(pca_110_test_output_svc_tuned[0]))
print ("F1 score for Testing set:       {:.10f}".format(pca_110_test_output_svc_tuned[1]))
# Out:
# Predicting labels for Training Set using SVC...
# Done!
# Prediction time for Training Set (secs): 3.535
# Accuracy score for training set: 0.9988412514484357
# F1 score for training set:       0.9988413114282713
#
#
# Predicting labels for Testing Set using SVC...
# Done!
# Prediction time for Testing Set (secs): 1.446
# Accuracy score for Testing set: 0.9427577483
# F1 score for Testing set:       0.9423382832

# %%
# Plotting SVC Testing CMs
title = 'Training & Testing Set Confusion Matricies for Tuned SVC on 110 Component PCA'
questionable_annot_colors = ([str(pca_110_train_output_svc_tuned[2][x, x]) for x in range(12)] + 
                             [str(pca_110_test_output_svc_tuned[2][x, x]) for x in range(12)])
plot_confusion_matricies(pca_110_train_output_svc_tuned[2],
                         pca_110_test_output_svc_tuned[2],
                         title, questionable_annot_colors)

# %% [markdown]
# ------
#
# ## Testing on the Tuned SVC on the Entire Featurespace

# %%
full_clf_svc_tuned_train_time = train_classifier(clf_svc_tuned, X_train, y_train.activity.values)
print(clf_svc_tuned)
# Out:
# Training SVC...
# Done!
# Training time (secs): 3.644
# SVC(C=100.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# Training metrics SVC entire dataset 
train_output_svc_tuned = predict_labels(clf_svc_tuned, X_train, y_train)
print ("Accuracy score for training set: {}".format(train_output_svc_tuned[0]))
print ("F1 score for training set:       {}".format(train_output_svc_tuned[1]))

# whitespace 
print('')
print('')

# Testing metrics SVC 
test_output_svc_tuned = predict_labels(clf_svc_tuned, X_test, y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(test_output_svc_tuned[0]))
print ("F1 score for Testing set:       {:.10f}".format(test_output_svc_tuned[1]))
# Out:
# Predicting labels for Training Set using SVC...
# Done!
# Prediction time for Training Set (secs): 7.444
# Accuracy score for training set: 0.991373760782799
# F1 score for training set:       0.9913744418050583
#
#
# Predicting labels for Testing Set using SVC...
# Done!
# Prediction time for Testing Set (secs): 3.099
# Accuracy score for Testing set: 0.9535104364
# F1 score for Testing set:       0.9532493847

# %%
# Plotting SVC Testing CMs
title = 'Training & Testing Set Confusion Matricies for Tuned SVC on Full Featureset'
questionable_annot_colors = ([str(train_output_svc_tuned[2][x, x]) for x in range(12)] + 
                             [str(test_output_svc_tuned[2][x, x]) for x in range(12)])
plot_confusion_matricies(train_output_svc_tuned[2],
                         test_output_svc_tuned[2],
                         title, questionable_annot_colors)

# %% [markdown]
# ### Accuracies vs Times Plot for final mold on PCA vs Entire Featureset

# %%
# setup figure with side by side plot 
fig, axes = plt.subplots(nrows=1, ncols=2, sharey=False, sharex=False)
fig.set_size_inches(15, 5) # Plot figure Size 

# setup accuracy and time lists 
training_accuracies = [pca_110_train_output_svc_tuned[0],
                      train_output_svc_tuned[0], 
                      0.996466431095]
testing_accuracies = [pca_110_test_output_svc_tuned[0],
                     test_output_svc_tuned[0],
                     0.9315068493]

training_times = [pca_110_clf_svc_tuned_train_time,
                 full_clf_svc_tuned_train_time]
train_pred_times = [pca_110_train_output_svc_tuned[3],
                   train_output_svc_tuned[3]]
test_pred_times = [pca_110_test_output_svc_tuned[3],
                  test_output_svc_tuned[3]]

plt.suptitle('Accuracies vs Training & Prediction Times for Tuned SVC on PCA Reduced Features vs Entire Feature Set',
             y=1.02, fontsize=18)

axes[0].plot([0, 1, 2], training_accuracies, '-o', color='lightseagreen', label='Training Accuracy')
axes[0].plot([0, 1, 2], testing_accuracies, '-o', color='tomato', label='Test Accuracy')
axes[1].plot(train_pred_times, '-o', color='tomato', label='Train Prediction Time')
axes[1].plot(training_times, '-o', color='lightseagreen', label='Total Training Time')
axes[1].plot(test_pred_times, '-o', color='violet', label='Test Prediction Time')

# set axis ranges and titles  
axes[0].set_ylim(0.92, 1.01)
axes[0].set_xlim(-0.25, 2.25)
axes[1].set_ylim(0, 12)
axes[1].set_xlim(-0.25, 1.25)
axes[0].set_xticks([0, 1, 2])
axes[0].set_xticklabels(['PCA Reduced Features', 'Entire Feature Space', 'Tri-Axial Features'], fontsize=12)
axes[0].set_ylabel('Accuracy', fontsize=15)
axes[1].set_ylabel('Time (seconds)', fontsize=15)
axes[1].set_xticks([0, 1])
axes[1].set_xticklabels(['PCA Reduced Features', 'Entire Feature Space'], fontsize=12)
fig.text(0.51, 0.02, 'Feature Space', ha='center', fontsize=15)
axes[0].set_title('Accuracy Comparison', fontsize=14)
axes[1].set_title('Training & Prediction Time Comparison', fontsize=14)

# annotations
def annotate_point(ax, point, points, loc=(-20, 20), color='lightseagreen', accuracy=True):
    axes[ax].annotate('{:.1f} {}'.format(points[point] * 100 if accuracy else points[point], 
                                        '%' if accuracy else 'sec'), 
            xy = (point, points[point]), xytext = loc,
            textcoords = 'offset points', ha = 'left', va = 'bottom', fontsize=12, 
            bbox = dict(boxstyle = 'round,pad=0.5', fc = color, alpha = 0.8),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3, rad=0', linewidth=1, color='darkgrey'))
    
annotate_point(0, 0, training_accuracies)
annotate_point(0, 1, training_accuracies)
annotate_point(0, 2, training_accuracies, loc=(-10, -30))
annotate_point(0, 0, testing_accuracies, color='tomato')
annotate_point(0, 1, testing_accuracies, color='tomato')
annotate_point(0, 2, testing_accuracies, color='tomato')
annotate_point(1, 0, training_times, loc=(-54, 7), accuracy=False)
annotate_point(1, 1, training_times, loc=(15, 20), accuracy=False)
annotate_point(1, 0, train_pred_times, loc=(-54, 30), color='tomato', accuracy=False)
annotate_point(1, 1, train_pred_times, loc=(15, -30), color='tomato', accuracy=False)
annotate_point(1, 0, test_pred_times, loc=(-54, -15), color='violet', accuracy=False)
annotate_point(1, 1, test_pred_times, loc=(15, -30), color='violet', accuracy=False)

axes[0].legend(fontsize=11)
axes[1].legend(fontsize=11)
plt.show()

# %% [markdown]
# ============================================================
# ============================================================
#
# # Machine Learning on RAW Triaxial Gyroscope and Accelerometer Data
#
# For comparison it was decided to create my own simplified feature vectors from the original RAW data to see how it compares to the performance of the PCA reduction and the entire feature space.

# %% [markdown]
# ### y_raw DataFrame creation

# %%
y_raw = pd.read_csv('/content/drive/My Drive/Colab Notebooks/hapt-data/RawData/labels.txt', sep=' ', header=None)

# Column 1: experiment number ID, 
# Column 2: user number ID, 
# Column 3: activity number ID 
# Column 4: Label start point (in number of signal log samples (recorded at 50Hz)) 
# Column 5: Label end point (in number of signal log samples)
y_raw.columns = ['Experiment_ID', 'User_ID', 'Activity_ID', 'Start_Point', 'End_Point']
y_raw[y_raw['Experiment_ID'] == 1].head()
# Out:
#    Experiment_ID  User_ID  Activity_ID  Start_Point  End_Point
# 0              1        1            5          250       1232
# 1              1        1            7         1233       1392
# 2              1        1            4         1393       2194
# 3              1        1            8         2195       2359
# 4              1        1            5         2360       3374

# %% [markdown]
# ### X_raw DataFrame creation

# %%
import os

# start with empty dataframes 
X_acc_raw = pd.DataFrame()
X_gyro_raw = pd.DataFrame()
# !ls
# cycle through files to build the X_Raw_dataframe 
for raw_file in os.listdir('/content/drive/My Drive/Colab Notebooks/hapt-data/RawData/'):
    if raw_file != 'labels.txt': # ignore labels
        
        # create a dataframe from the file
        file_frame = pd.read_csv(('/content/drive/My Drive/Colab Notebooks/hapt-data/RawData/' + raw_file), sep=' ', header=None)
        
        # need to add the experiment ID and user ID to the dataframe
        x = list(filter(str.isdigit, raw_file))
        # x = ["0", "1", "2"]
        y = ''.join(x) # converting list into string
        numbers = y
        exp_ID = int(numbers[1]) if numbers[0] == '0' else int(numbers[0:2])
        user_ID = int(numbers[-1]) if numbers[2] == '0' else int(numbers[2:-1])
        
        # add experiment ID and user ID columns 
        file_frame['Experiment_ID'] = exp_ID
        file_frame['User_ID'] = user_ID
        
        # setup columns and append to appropriate dataframe 
        if raw_file.startswith('acc'):
            file_frame = file_frame.rename(
                columns = {0: 'tRawAcc-1', 1: 'tRawAcc-2', 2: 'tRawAcc-3'})
            X_acc_raw = X_acc_raw.append(file_frame)
        else:
            file_frame = file_frame.rename(
                columns = {0: 'tRawGyro-1', 1: 'tRawGyro-2', 2: 'tRawGyro-3'})
            X_gyro_raw = X_gyro_raw.append(file_frame)
            
print (len(X_acc_raw))
print (X_acc_raw.head())
print ('')
print(len(X_gyro_raw))
print (X_gyro_raw.head())
# Out:
# adc.json  drive  sample_data
# 1122772
#    tRawAcc-1  tRawAcc-2  tRawAcc-3  Experiment_ID  User_ID
# 0   0.188889  -0.016667   1.019445             34        1
# 1   0.188889  -0.016667   1.019445             34        1
# 2   0.229167  -0.022222   1.031945             34        1
# 3   0.238889  -0.027778   1.013889             34        1
# 4   0.219444  -0.015278   0.972222             34        1
#
# 1122772
#    tRawGyro-1  tRawGyro-2  tRawGyro-3  Experiment_ID  User_ID
# 0   -0.286801   -0.304211    0.070555             48        2
# 1   -0.194866   -0.497550    0.081856             48        2
# 2   -0.145386   -0.623388    0.082161             48        2
# 3   -0.093768   -0.717461    0.081856             48        2
# 4   -0.095295   -0.274889    0.022602             48        2

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# List .txt files in the root.
#
# Search query reference:
# https://developers.google.com/drive/v2/web/search-parameters
listed = drive.ListFile({'q': "title contains '.txt' and 'root' in parents"}).GetList()
for file in listed:
  print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title https://oladblo.txt, id 1AskatAUkL4xHGXy3soyUm4tIG_F5U6xT

# %% [markdown]
# ### Understanding Start and Stop Points
#
# The Start and Stop point are the rows in each experiment file that correspond to the Activity ID that's being performed that particular moment.  In order to verify this is the case a series of start and stop points were plotted over a section of one of the experiment signals

# %%
# the start point and end point correspond to when the user does the specific activity.
y_raw[(y_raw['Experiment_ID'] == 1) & (y_raw['User_ID'] == 1) & (y_raw['Start_Point'] >= 8000)].head()
# Out:
#     Experiment_ID  User_ID  Activity_ID  Start_Point  End_Point
# 13              1        1            1         8356       9250
# 14              1        1            1         9657      10567
# 15              1        1            1        10750      11714
# 16              1        1            3        13191      13846
# 17              1        1            2        14069      14699

# %%
X_acc_raw[(X_acc_raw['Experiment_ID'] == 1) & (X_acc_raw['User_ID'] == 1)][
    ['tRawAcc-1', 'tRawAcc-2', 'tRawAcc-3']][7500:15000].plot(figsize=(10, 5))

plt.suptitle('Verification of Start and Stop Points for Raw Data', fontsize=16)

# check to see if start and stop points align with increased activity 
# values are taken from the dataframe.head above 
plt.axvline(8356, color='m', linestyle='dashed')
plt.axvline(9250, color='m', linestyle='dashed')
plt.axvspan(8356, 9250, alpha=0.5, color='plum')

plt.axvline(9657, color='k', linestyle='dashed')
plt.axvline(10567, color='k', linestyle='dashed')
plt.axvspan(9657, 10567, alpha=0.5, color='black')

plt.axvline(10750, color='r', linestyle='dashed')
plt.axvline(11714, color='r', linestyle='dashed')
plt.axvspan(10750, 11714, alpha=0.5, color='indianred')

plt.axvline(13191, color='b', linestyle='dashed')
plt.axvline(13846, color='b', linestyle='dashed')
plt.axvspan(13191, 13846, alpha=0.5, color='cornflowerblue')

plt.axvline(14069, color='orange', linestyle='dashed')
plt.axvline(14699, color='orange', linestyle='dashed')
plt.axvspan(14069, 14699, alpha=0.5, color='coral')

plt.show()

# %%
# build the new data frame 
# Starting with Min, Max & Mean 
X_processed = pd.DataFrame()

for index, row in y_raw.iterrows():
    row_list = []
    X_acc_activity = X_acc_raw[X_acc_raw['Experiment_ID'] == row['Experiment_ID']][row['Start_Point']:row['End_Point']]
    X_gyro_activity = X_gyro_raw[X_gyro_raw['Experiment_ID'] == row['Experiment_ID']][row['Start_Point']:row['End_Point']]
    
    row_list.append([X_acc_activity['tRawAcc-1'].mean(), 
                     X_acc_activity['tRawAcc-2'].mean(), 
                     X_acc_activity['tRawAcc-3'].mean(),
                     X_acc_activity['tRawAcc-1'].min(), 
                     X_acc_activity['tRawAcc-2'].min(), 
                     X_acc_activity['tRawAcc-3'].min(),
                     X_acc_activity['tRawAcc-1'].max(), 
                     X_acc_activity['tRawAcc-2'].max(), 
                     X_acc_activity['tRawAcc-3'].max(),
                     X_gyro_activity['tRawGyro-1'].mean(), 
                     X_gyro_activity['tRawGyro-2'].mean(), 
                     X_gyro_activity['tRawGyro-3'].mean(),
                     X_gyro_activity['tRawGyro-1'].min(), 
                     X_gyro_activity['tRawGyro-2'].min(), 
                     X_gyro_activity['tRawGyro-3'].min(),
                     X_gyro_activity['tRawGyro-1'].max(), 
                     X_gyro_activity['tRawGyro-2'].max(), 
                     X_gyro_activity['tRawGyro-3'].max()])
    X_processed = X_processed.append(row_list)

X_processed.columns = ['tRawAcc-Mean-1', 'tRawAcc-Mean-2', 'tRawAcc-Mean-3',
                      'tRawAcc-Min-1', 'tRawAcc-Min-2', 'tRawAcc-Min-3', 
                      'tRawAcc-Max-1', 'tRawAcc-Max-2', 'tRawAcc-Max-3',
                      'tRawGyro-Mean-1', 'tRawGyro-Mean-2', 'tRawGyro-Mean-3',
                      'tRawGyro-Min-1', 'tRawGyro-Min-2', 'tRawGyro-Min-3', 
                      'tRawGyro-Max-1', 'tRawGyro-Max-2', 'tRawGyro-Max-3']
X_processed.reset_index(drop=True, inplace=True)

print ('The X dataframe contains      {} rows'.format(len(X_processed)))
print ('The Target dataframe contains {} rows'.format(len(y_raw)))
X_processed.head()
# Out:
# The X dataframe contains      1214 rows
# The Target dataframe contains 1214 rows
#    tRawAcc-Mean-1  tRawAcc-Mean-2  ...  tRawGyro-Max-2  tRawGyro-Max-3
# 0        1.020468       -0.130783  ...        0.076664        0.036346
# 1        0.990898       -0.123908  ...        0.719294        0.573297
# 2        0.834622        0.333510  ...        1.128574        0.502131
# 3        0.944089       -0.087830  ...        0.430660        1.931250
# 4        1.008583       -0.248658  ...        0.095906        0.859182
#
# [5 rows x 18 columns]

# %% [markdown]
# ### Start Machine Learning on created Dataset from the RAW data.
#
# First we need to split the data into training and testing sets

# %%
# import train_test_split
from sklearn.model_selection import train_test_split

# create y_target dataframe which only contains the Activity ID
y_target = y_raw['Activity_ID']

X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y_target, test_size=0.30, random_state=42)

# %%
# Need to retune SVC algorithm 
# C and gamma parameter rangers 
C_range = np.logspace(-2, 3, 6)
gamma_range = np.logspace(-2, 3, 6)

parameter_grid = {'gamma': gamma_range, 'C': C_range}
scorer = make_scorer(accuracy_score)
svc_raw = SVC()
clf_gs_raw = GridSearchCV(svc_raw, parameter_grid, scoring=scorer)

clf_gs_raw.fit(X_train, y_train)
clf_svc_raw_tuned = clf_gs_raw.best_estimator_ 

# Fit the tuned model to training data
clf_svc_tuned_raw_train_time = train_classifier(clf_svc_raw_tuned, X_train, y_train)
print( clf_gs_raw.best_params_)
print( clf_svc_raw_tuned )
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Training SVC...
# Done!
# Training time (secs): 0.022
# {'C': 100.0, 'gamma': 0.1}
# SVC(C=100.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
# Training metrics SVC entire dataset 
train_output_svc_raw_tuned = predict_labels(clf_svc_raw_tuned, X_train, y_train)
print ("Accuracy score for training set: {}".format(train_output_svc_raw_tuned[0]))
print ("F1 score for training set:       {}".format(train_output_svc_raw_tuned[1]))

# whitespace 
print ('')
print ('')

# Testing metrics SVC 
test_output_svc_raw_tuned = predict_labels(clf_svc_raw_tuned, X_test, y_test, False)
print ("Accuracy score for Testing set: {:.10f}".format(test_output_svc_raw_tuned[0]))
print ("F1 score for Testing set:       {:.10f}".format(test_output_svc_raw_tuned[1]))
# Out:
# Predicting labels for Training Set using SVC...
# Done!
# Prediction time for Training Set (secs): 0.032
# Accuracy score for training set: 0.9964664310954063
# F1 score for training set:       0.9964674470361516
#
#
# Predicting labels for Testing Set using SVC...
# Done!
# Prediction time for Testing Set (secs): 0.010
# Accuracy score for Testing set: 0.9315068493
# F1 score for Testing set:       0.9310177397

# %%
# Plotting Tuned SVC Training & Testing CMs
title = 'Training & Testing Set Confusion Matricies for SVC on RAW Tri-Axial Data'
questionable_annot_colors = ([str(train_output_svc_raw_tuned[2][x, x]) for x in range(12)] + 
                             [str(test_output_svc_raw_tuned[2][x, x]) for x in range(12)])
plot_confusion_matricies(train_output_svc_raw_tuned[2],
                         test_output_svc_raw_tuned[2],
                         title, questionable_annot_colors)
